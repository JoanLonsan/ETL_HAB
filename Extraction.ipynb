# %% [markdown]
# # Extraction Notebook
#
# **Título:**
# - Extracción de datos desde la API de Spotify
#
# **Descripción:**
# - Este notebook se encarga de obtener datos de la API de Spotify, incluyendo los top 50 canciones por país, top canciones por género y otros datos relevantes para el análisis. ¡Prepárate para el gran retorno! En este apartado, nuestros datos viajarán desde la nube hasta un impresionante DataFrame de pandas, listo para la acción. ¡Y eso no es todo! Como parte de nuestro emocionante espectáculo de datos, también generaremos un archivo en formato PICKLE. ¡Esto promete ser épico!
#
# **Returns:**
# - `df_unprocessed.pkl` (DataFrame): El DataFrame sin procesar obtenido en la fase de extracción.

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np

from requests import get, post
import base64
import json

import time
from datetime import datetime, timedelta

# %%
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Credenciales desde .env

# %%
# Client ID y Client Secret
client_id = os.getenv("SPOTIFY_CLIENT_ID")
client_secret = os.getenv("SPOTIFY_CLIENT_SECRET")

# %% [markdown]
# ## API SPOTIFY - Documentación
#
# https://developer.spotify.com/documentation/web-api

# %% [markdown]
# ## Código Color
#
# Para incluir en los print

# %%
colors = {
    "black": "\033[30m",
    "red": "\033[31m",
    "green": "\033[32m",
    "yellow": "\033[33m",
    "blue": "\033[34m",
    "purple": "\033[35m",
    "cyan": "\033[36m",
    "white": "\033[37m",
    "light_gray": "\033[37;1m",
    "reset": "\033[0m"
}

# %% [markdown]
# ## Códigos de País
#
# | Código | País                              | Código | País                              |
# |-------|-----------------------------------|-------|-----------------------------------|
# | AD     | Andorra                           | MD     | Moldova, Republic of              |
# | AE     | United Arab Emirates              | ME     | Montenegro                        |
# | AF     | Afghanistan                       | MF     | Saint Martin (French part)        |
# | AG     | Antigua and Barbuda               | MG     | Madagascar                        |
# | AI     | Anguilla                          | MH     | Marshall Islands                  |
# | AL     | Albania                           | MK     | North Macedonia                   |
# | AM     | Armenia                           | ML     | Mali                              |
# | AO     | Angola                            | MM     | Myanmar                           |
# | AQ     | Antarctica                        | MN     | Mongolia                          |
# | AR     | Argentina                         | MO     | Macao                             |
# | AS     | American Samoa                    | MP     | Northern Mariana Islands          |
# | AT     | Austria                           | MQ     | Martinique                        |
# | AU     | Australia                         | MR     | Mauritania                        |
# | AW     | Aruba                             | MS     | Montserrat                        |
# | AX     | Åland Islands                     | MT     | Malta                             |
# | AZ     | Azerbaijan                        | MU     | Mauritius                         |
# | BA     | Bosnia and Herzegovina            | MV     | Maldives                          |
# | BB     | Barbados                          | MW     | Malawi                            |
# | BD     | Bangladesh                        | MX     | Mexico                            |
# | BE     | Belgium                           | MY     | Malaysia                          |
# | BF     | Burkina Faso                      | MZ     | Mozambique                        |
# | BG     | Bulgaria                          | NA     | Namibia                           |
# | BH     | Bahrain                           | NC     | New Caledonia                     |
# | BI     | Burundi                           | NE     | Niger                             |
# | BJ     | Benin                             | NF     | Norfolk Island                    |
# | BL     | Saint Barthélemy                  | NG     | Nigeria                           |
# | BM     | Bermuda                           | NI     | Nicaragua                         |
# | BN     | Brunei Darussalam                 | NL     | Netherlands, Kingdom of           |
# | BO     | Bolivia, Plurinational State of   | NO     | Norway                            |
# | BQ     | Bonaire, Sint Eustatius and Saba  | NP     | Nepal                             |
# | BR     | Brazil                            | NR     | Nauru                             |
# | BS     | Bahamas                           | NU     | Niue                              |
# | BT     | Bhutan                            | NZ     | New Zealand                       |
# | BV     | Bouvet Island                     | OM     | Oman                              |
# | BW     | Botswana                          | PA     | Panama                            |
# | BY     | Belarus                           | PE     | Peru                              |
# | BZ     | Belize                            | PF     | French Polynesia                  |
# | CA     | Canada                            | PG     | Papua New Guinea                  |
# | CC     | Cocos (Keeling) Islands           | PH     | Philippines                       |
# | CD     | Congo, Democratic Republic of     | PK     | Pakistan                          |
# | CF     | Central African Republic          | PL     | Poland                            |
# | CG     | Congo                             | PM     | Saint Pierre and Miquelon         |
# | CH     | Switzerland                       | PN     | Pitcairn                          |
# | CI     | Côte d'Ivoire                     | PR     | Puerto Rico                       |
# | CK     | Cook Islands                      | PS     | Palestine, State of               |
# | CL     | Chile                             | PT     | Portugal                          |
# | CM     | Cameroon                          | PW     | Palau                             |
# | CN     | China                             | PY     | Paraguay                          |
# | CO     | Colombia                          | QA     | Qatar                             |
# | CR     | Costa Rica                        | RE     | Réunion                           |
# | CU     | Cuba                              | RO     | Romania                           |
# | CV     | Cabo Verde                        | RS     | Serbia                            |
# | CW     | Curaçao                           | RU     | Russian Federation                |
# | CX     | Christmas Island                  | RW     | Rwanda                            |
# | CY     | Cyprus                            | SA     | Saudi Arabia                      |
# | CZ     | Czechia                           | SB     | Solomon Islands                   |
# | DE     | Germany                           | SC     | Seychelles                        |
# | DJ     | Djibouti                          | SD     | Sudan                             |
# | DK     | Denmark                           | SE     | Sweden                            |
# | DM     | Dominica                          | SG     | Singapore                         |
# | DO     | Dominican Republic                | SH     | Saint Helena, Ascension and Tristan da Cunha |
# | DZ     | Algeria                           | SI     | Slovenia                          |
# | EC     | Ecuador                           | SJ     | Svalbard and Jan Mayen            |
# | EE     | Estonia                           | SK     | Slovakia                          |
# | EG     | Egypt                             | SL     | Sierra Leone                      |
# | EH     | Western Sahara                    | SM     | San Marino                        |
# | ER     | Eritrea                           | SN     | Senegal                           |
# | ES     | Spain                             | SO     | Somalia                           |
# | ET     | Ethiopia                          | SR     | Suriname                          |
# | FI     | Finland                           | SS     | South Sudan                       |
# | FJ     | Fiji                              | ST     | Sao Tome and Principe             |
# | FK     | Falkland Islands (Malvinas)       | SV     | El Salvador                       |
# | FM     | Micronesia, Federated States of   | SX     | Sint Maarten (Dutch part)         |
# | FO     | Faroe Islands                     | SY     | Syrian Arab Republic              |
# | FR     | France                            | SZ     | Eswatini                          |
# | GA     | Gabon                             | TC     | Turks and Caicos Islands          |
# | GB     | United Kingdom of Great Britain and Northern Ireland | TD | Chad            |
# | GD     | Grenada                           | TF     | French Southern Territories       |
# | GE     | Georgia                           | TG     | Togo                              |
# | GF     | French Guiana                     | TH     | Thailand                          |
# | GG     | Guernsey                          | TJ     | Tajikistan                        |
# | GH     | Ghana                             | TK     | Tokelau                           |
# | GI     | Gibraltar                         | TL     | Timor-Leste                       |
# | GL     | Greenland                         | TM     | Turkmenistan                      |
# | GM     | Gambia                            | TN     | Tunisia                           |
# | GN     | Guinea                            | TO     | Tonga                             |
# | GP     | Guadeloupe                        | TR     | Türkiye                           |
# | GQ     | Equatorial Guinea                 | TT     | Trinidad and Tobago               |
# | GR     | Greece                            | TV     | Tuvalu                            |
# | GS     | South Georgia and the South Sandwich Islands

# %%
countries_dict = {'Andorra': 'AD', 'Moldova, Republic of': 'MD', 'United Arab Emirates': 'AE', 'Montenegro': 'ME',
                  'Afghanistan': 'AF', 'Saint Martin (French part)': 'MF', 'Antigua and Barbuda': 'AG',
                  'Madagascar': 'MG', 'Anguilla': 'AI', 'Marshall Islands': 'MH', 'Albania': 'AL', 'North Macedonia': 'MK',
                  'Armenia': 'AM', 'Mali': 'ML', 'Angola': 'AO', 'Myanmar': 'MM', 'Antarctica': 'AQ', 'Mongolia': 'MN',
                  'Argentina': 'AR', 'Macao': 'MO', 'American Samoa': 'AS', 'Northern Mariana Islands': 'MP', 'Austria': 'AT',
                  'Martinique': 'MQ', 'Australia': 'AU', 'Mauritania': 'MR', 'Aruba': 'AW', 'Montserrat': 'MS', 'Åland Islands': 'AX',
                  'Malta': 'MT', 'Azerbaijan': 'AZ', 'Mauritius': 'MU', 'Bosnia and Herzegovina': 'BA', 'Maldives': 'MV',
                  'Barbados': 'BB', 'Malawi': 'MW', 'Bangladesh': 'BD', 'Mexico': 'MX', 'Belgium': 'BE', 'Malaysia': 'MY',
                  'Burkina Faso': 'BF', 'Mozambique': 'MZ', 'Bulgaria': 'BG', 'Namibia': 'NA', 'Bahrain': 'BH', 'New Caledonia': 'NC',
                  'Burundi': 'BI', 'Niger': 'NE', 'Benin': 'BJ', 'Norfolk Island': 'NF', 'Saint Barthélemy': 'BL', 'Nigeria': 'NG',
                  'Bermuda': 'BM', 'Nicaragua': 'NI', 'Brunei Darussalam': 'BN', 'Netherlands, Kingdom of': 'NL',
                  'Bolivia, Plurinational State of': 'BO', 'Norway': 'NO', 'Bonaire, Sint Eustatius and Saba': 'BQ',
                  'Nepal': 'NP', 'Brazil': 'BR', 'Nauru': 'NR', 'Bahamas': 'BS', 'Niue': 'NU', 'Bhutan': 'BT', 'New Zealand': 'NZ',
                  'Bouvet Island': 'BV', 'Oman': 'OM', 'Botswana': 'BW', 'Panama': 'PA', 'Belarus': 'BY', 'Peru': 'PE', 'Belize': 'BZ',
                  'French Polynesia': 'PF', 'Canada': 'CA', 'Papua New Guinea': 'PG', 'Cocos (Keeling) Islands': 'CC',
                  'Philippines': 'PH', 'Congo, Democratic Republic of': 'CD', 'Pakistan': 'PK', 'Central African Republic': 'CF',
                  'Poland': 'PL', 'Congo': 'CG', 'Saint Pierre and Miquelon': 'PM', 'Switzerland': 'CH', 'Pitcairn': 'PN',
                  "Côte d'Ivoire": 'CI', 'Puerto Rico': 'PR', 'Cook Islands': 'CK', 'Palestine, State of': 'PS', 'Chile': 'CL',
                  'Portugal': 'PT', 'Cameroon': 'CM', 'Palau': 'PW', 'China': 'CN', 'Paraguay': 'PY', 'Colombia': 'CO', 'Qatar': 'QA',
                  'Costa Rica': 'CR', 'Réunion': 'RE', 'Cuba': 'CU', 'Romania': 'RO', 'Cabo Verde': 'CV', 'Serbia': 'RS',
                  'Curaçao': 'CW', 'Russian Federation': 'RU', 'Christmas Island': 'CX', 'Rwanda': 'RW', 'Cyprus': 'CY',
                  'Saudi Arabia': 'SA', 'Czechia': 'CZ', 'Solomon Islands': 'SB', 'Germany': 'DE', 'Seychelles': 'SC', 'Djibouti': 'DJ',
                  'Sudan': 'SD', 'Denmark': 'DK', 'Sweden': 'SE', 'Dominica': 'DM', 'Singapore': 'SG', 'Dominican Republic': 'DO',
                  'Saint Helena, Ascension and Tristan da Cunha': 'SH', 'Algeria': 'DZ', 'Slovenia': 'SI', 'Ecuador': 'EC',
                  'Svalbard and Jan Mayen': 'SJ', 'Estonia': 'EE', 'Slovakia': 'SK', 'Egypt': 'EG', 'Sierra Leone': 'SL',
                  'Western Sahara': 'EH', 'San Marino': 'SM', 'Eritrea': 'ER', 'Senegal': 'SN', 'Spain': 'ES', 'Somalia': 'SO',
                  'Ethiopia': 'ET', 'Suriname': 'SR', 'Finland': 'FI', 'South Sudan': 'SS', 'Fiji': 'FJ', 'Sao Tome and Principe': 'ST',
                  'Falkland Islands (Malvinas)': 'FK', 'El Salvador': 'SV', 'Micronesia, Federated States of': 'FM',
                  'Sint Maarten (Dutch part)': 'SX', 'Faroe Islands': 'FO', 'Syrian Arab Republic': 'SY', 'France': 'FR',
                  'Eswatini': 'SZ', 'Gabon': 'GA', 'Turks and Caicos Islands': 'TC', 'United Kingdom of Great Britain and Northern Ireland': 'GB',
                  'Chad': 'TD', 'Grenada': 'GD', 'French Southern Territories': 'TF', 'Georgia': 'GE', 'Togo': 'TG', 'French Guiana': 'GF',
                  'Thailand': 'TH', 'Guernsey': 'GG', 'Tajikistan': 'TJ', 'Ghana': 'GH', 'Tokelau': 'TK', 'Gibraltar': 'GI',
                  'Timor-Leste': 'TL', 'Greenland': 'GL', 'Turkmenistan': 'TM', 'Gambia': 'GM', 'Tunisia': 'TN', 'Guinea': 'GN', 'Tonga': 'TO',
                  'Guadeloupe': 'GP', 'Türkiye': 'TR', 'Equatorial Guinea': 'GQ', 'Trinidad and Tobago': 'TT', 'Greece': 'GR', 'Tuvalu': 'TV', 'Italy': 'IT'}
inv_countries_dict = {v: k for k, v in countries_dict.items()}

# %% [markdown]
# # Funciones

# %% [markdown]
# ## Obtener Token
# ### 'get_token()'
# Se incluye una validación de tiempo restante, para no estar pidiendo un nuevo token siempre, o llegar a quedarnos sin él.
#
# Con esta comprobación, si no existe el token, o si el tiempo restante ha llegado a 0, se genera uno nuevo y podemos incluir la funcion en cada llamada a la API.
#
# ___
# *Note that the access token is valid for 1 hour (3600 seconds).
# After that time, the token expires and you need to request a new one.*
#
# ___
# RUTA Docu para hacer el Encode
#
# https://developer.spotify.com/documentation/web-api/tutorials/client-credentials-flow
#
# https://github.com/spotify/web-api-examples/blob/master/authorization/client_credentials/app.js

# %%
# Definir una variable global para almacenar el token y el tiempo restante
global_access_token = None
token_expiry_time = 0

def get_token(print_token = False):
    """
    Obtiene un token de acceso a la API de Spotify utilizando el flujo de credenciales de cliente.
    Args:
        print_token (bool, optional): Indica si se debe imprimir el tiempo restante del token.
    Por defecto es False.
    Returns:
        str: El token de acceso a la API de Spotify.
    """
    global global_access_token
    global token_expiry_time
    
    current_time = int(time.time())
    if global_access_token is None or current_time >= token_expiry_time:
        token_url = 'https://accounts.spotify.com/api/token'
        client_credentials = f"{client_id}:{client_secret}"
        client_credentials_b64 = base64.b64encode(client_credentials.encode()).decode()
        headers = {'Authorization': f'Basic {client_credentials_b64}'}
        params = {'grant_type': 'client_credentials'}
        response = post(token_url, headers=headers, data=params)
        token_data = response.json()
        global_access_token = token_data['access_token']
        token_expiry_time = current_time + token_data['expires_in'] - 60

    # Calcular tiempo restante del token
    tiempo_restante = datetime.fromtimestamp(token_expiry_time) - datetime.now()
    minutos_restantes = tiempo_restante.seconds // 60
    segundos_restantes = tiempo_restante.seconds % 60
    if print_token:
        print(f"{colors['light_gray']}Tiempo restante de token: {minutos_restantes} minutos {segundos_restantes} segundos{colors['reset']}")
        
    return global_access_token

# %% [markdown]
# ## Headers
# ### 'get_headers()'

# %%
def get_headers(token):
    """
    Genera los encabezados necesarios para realizar una solicitud a la API de Spotify utilizando un token de acceso.
    Args:
        token (str): El token de acceso a la API de Spotify.
    Returns:
        dict: Un diccionario que contiene los encabezados necesarios para la solicitud, incluyendo el token de acceso.
    Example:
    >>> access_token = get_token()
    >>> headers = get_headers(access_token)
    """
    return {"Authorization": f"Bearer {token}"}

# %% [markdown]
# ## Codigos de Paises
# ### get_country_code()

# %%
def get_country_code():
    """
    Solicita al usuario el nombre o el código del país para buscar información y devuelve el código del país.
    Returns:
    str or None: El código del país ingresado por el usuario, o None si no se encuentra en la lista.
    Note:
    Para consultar la lista completa de países y códigos, consulte la sección [Códigos de País] en este documento.
    """
    user_input = input(f"{colors['yellow']}Ingresa el nombre o el código del país para buscar información: ").strip().title()
    if user_input in countries_dict:
        return countries_dict[user_input]
    elif user_input.upper() in countries_dict.values():
        return user_input.upper()
    else:
        print("El país o código ingresado no se encuentra en la lista.")
        return None

# %% [markdown]
# ## Atributos de Cancion
# ### get_track_feature(id)

# %%
# Dict de Claves Musica
key_dict = {
    -1: "No detectada",
    0: "C",
    1: "C♯/D♭",
    2: "D",
    3: "D♯/E♭",
    4: "E",
    5: "F",
    6: "F♯/G♭",
    7: "G",
    8: "G♯/A♭",
    9: "A",
    10: "A♯/B♭",
    11: "B"
}

# %%
# Ft Auxiliar Acusticness
def is_acoustic(acousticness, umbral=0.5):
    """
    Determina si una canción es acústica basándose en su valor de acousticness.
    Args:
    - acousticness (float): El valor de acousticness de la canción.
    - umbral (float): El umbral a partir del cual considerar que una canción es acústica. Por defecto, 0.5.
    Returns:
    - bool: True si la canción es acústica, False en caso contrario.
    """
    return acousticness > umbral

# %%
# Print Auxiliar Get_Features
def print_features(features):
    """
    Imprime las características de una pista de Spotify.
    Args:
    - features (dict): Un diccionario que contiene las características de la pista, como acousticness, danceability, duration_ms, etc.
    """
    key = key_dict.get(features['key'], "No válida")
    print(f"Key {key}")
    dance_perc = "{:.2f}".format(features['danceability'] * 100)
    print(f"Bailable al {dance_perc}%")
    duracion_ms = features['duration_ms']
    duracion_seg = duracion_ms / 1000
    minutos = int (duracion_seg // 60)
    segundos = int(duracion_seg % 60)
    print(f"Duracion: {minutos}mins {segundos}segs")
    acoustic = is_acoustic(features['acousticness'], umbral=0.3)
    print(f"Acústica? {acoustic}")

# %%
def get_track_feature(id, print_feat = False):
    """
    Obtiene las características de una pista de Spotify utilizando su ID.
    Args:
        id (str): El ID de la pista de Spotify.
        print_feat (bool, optional): Indica si se deben imprimir las características de la pista. 
            Por defecto es False.
    Returns:
        dict: Un diccionario que contiene las características de la pista.
    """
    endpoint = f"https://api.spotify.com/v1/audio-features/{id}"
    token = get_token()
    headers = get_headers(token)
    response = get(url = endpoint, headers = headers)
    data = response.json()
    if print_feat == True:
        print_features(data)
    return data

# %% [markdown]
# ## Top 50 por Paises
# ### top50_by_country()

# %%
def top50_by_country(country=None, print_feat=False):
    """
    Esta función obtiene la lista de reproducción Top 50 de un país especificado por el usuario desde Spotify.
    Args:
    - country (str, opcional): El nombre del país para el cual se desea obtener el Top 50.
    Si no se proporciona, se solicitará al usuario que ingrese el país a través de la entrada estándar.
    - print_features (bool, opcional): Un indicador booleano que controla si se deben imprimir las características de las pistas.
    Returns:
    - tuple: Una tupla que contiene una lista de IDs de canciones correspondientes al Top 50 del país especificado y una lista de diccionarios,
    donde cada diccionario contiene la información de una pista en el Top 50 del país especificado, incluidas las características si se solicitan.
    """
    if country is None:
        country = input(f"{colors['yellow']}Top 50 de...{colors['reset']}")
    token = get_token()
    search_headers = get_headers(token)
    query = f"top 50 {country}"
    search_url = f"https://api.spotify.com/v1/search?q={query}&type=playlist"
    response = get(url=search_url, headers=search_headers)
    data = response.json()
    playlist_id = data['playlists']['items'][0]['id']
    playlist_headers = get_headers(token)
    playlist_url = f"https://api.spotify.com/v1/playlists/{playlist_id}"
    response = get(url=playlist_url, headers=playlist_headers)
    data = response.json()
    ids = []
    tracks_info = []
    headers = get_headers(token)
    print(f"{colors['green']}-----   TOP 50 de {country.upper()}     -----{colors['reset']}")
    for i, song in enumerate(data['tracks']['items'], 1):
        print(f"{colors['cyan']}{i}.{colors['reset']}")
        print(f"{colors['blue']}Cancion > {colors['reset']}{song['track']['name']}")
        id = song['track']['id']
        ids.append(id)
        endpoint = f"https://api.spotify.com/v1/tracks/{id}"
        track_response = get(url=endpoint, headers=headers)
        track_data = track_response.json()
        if print_feat:
            print(f"{colors['blue']}Popularidad > {colors['reset']}{track_data['popularity']}")
            print(f"{colors['blue']}Artista > {colors['reset']}{song['track']['artists'][0]['name']}")
        features = get_track_feature(id, print_feat)
        track_info = {
            'Pais': country.upper(),
            'Orden en el Top 50': i,
            'Nombre de la Cancion': song['track']['name'],
            'Popularidad': track_data['popularity'],
            'Artista': song['track']['artists'][0]['name']
        }
        track_info.update(features)
        tracks_info.append(track_info)
    return ids, tracks_info

# %% [markdown]
# ## Top Artist by Genre

# %% [markdown]
# ### top_artist_by_genre(genre)
# ### get_artist_top10_tracks_features(artist_id)

# %%
def get_artist_by_genre(genre):
    token = get_token()
    url = 'https://api.spotify.com/v1/search'
    headers = get_headers(token)
    params = {
        'q': f'genre:"{genre}"',
        'type': 'artist',
        'limit': 10
    }

    response = get(url, headers=headers, params=params)
    return response

# %%
def get_artist_top10_tracks_features(href):
    token = get_token()
    headers = get_headers(token)
    # https://api.spotify.com/v1/artists/{id}/top-tracks
    endpoint = f"{href}/top-tracks"
    response = get(url=endpoint, headers=headers)
    top_info = response.json()
    return top_info

# %% [markdown]
# # DATAFRAMES

# %% [markdown]
# ## Creacion del DataFrame - Top50 por Paises
# ### df_create_top50()

# %%
def df_normalize_country(country):
    """
    Normaliza el nombre de un país.
    Parameters:
    country (str): El nombre del país.
    Returns:
    str: El nombre normalizado del país, o el nombre original si no se encuentra en el diccionario inverso.
    """
    normalized_name = inv_countries_dict.get(country.upper())
    if normalized_name:
        return normalized_name
    return country

# %%
def df_get_country_list():
    """
    Obtiene una lista de países ingresados por el usuario.
    Returns:
    list: Una lista de países normalizados ingresados por el usuario.
    """
    countries = []
    print(f"{colors['blue']}¿De qué países deseas obtener el TOP 50?{colors['reset']}")
    print(f"{colors['yellow']}Inserta 'STOP' cuando hayas acabado{colors['reset']}")
    while True:
        answer = input().strip().title()
        if answer == "Stop":
            break
        normalized_country = df_normalize_country(answer)
        if normalized_country in countries_dict:
            if normalized_country not in countries:
                countries.append(normalized_country)
                print(f"{colors['green']}'{normalized_country}' agregado a la lista{colors['reset']}")
            else:
                print(f"{colors['yellow']}El país '{normalized_country}' ya está en la lista.{colors['reset']}")
        else:
            print(f"{colors['red']}El país '{normalized_country}' no está en la lista de países válidos.\nPor favor, intenta de nuevo.{colors['reset']}")
    print(countries)
    return countries

# %%
def df_create_top50():
    """
    Esta función crea un nuevo DataFrame combinando la información de las 50 mejores canciones de varios países.
    Utiliza las funciones df_get_country_list() para obtener una lista de países y top50_by_country(country) para obtener la información de las 50 mejores canciones de cada país.
    Returns:
    pandas.DataFrame: Un DataFrame que contiene la información combinada de las 50 mejores canciones de varios países.
    """
    # Consultar de que paises se quiere obtener informacion de su TOP50
    countries = df_get_country_list()
    # Obtención de los datos del TOP50
    all_tracks_info = []
    for country in countries:
        tracks_info = top50_by_country(country)
        all_tracks_info.extend(tracks_info)
    # Creación del DataFrame
    data_list = []
    for item in all_tracks_info[1::2]:
        for country in item:
            row_data = {}
            for key, value in country.items():
                row_data[key] = value
            data_list.append(row_data)

    df = pd.DataFrame(data_list)
    directory = "./df_unprocessed/"
    if not os.path.exists(directory):
        os.makedirs(directory)
    df.to_pickle(f"{directory}/df_top50_unprocessed.pkl")
    return df

# %%
def feature_explanation(columna):
    """
    Esta función imprime la explicación de la columna especificada.
    Args:
    columna (str): El nombre de la columna a consultar.
    Returns:
    None
    """
    explicaciones = {
        'Pais': 'El país al que pertenece la canción.',
        'Orden en el Top 50': 'La posición de la canción en el Top 50 de su país.',
        'Nombre de la Cancion': 'El nombre de la canción.',
        'Popularidad': 'La popularidad de la canción.',
        'Artista': 'El nombre del artista o grupo que interpreta la canción.',
        'danceability': 'Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.',
        'energy': 'Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale. Perceptual features contributing to this attribute include dynamic range, perceived loudness, timbre, onset rate, and general entropy.',
        'key': 'The key the track is in. Integers map to pitches using standard Pitch Class notation. E.g. 0 = C, 1 = C♯/D♭, 2 = D, and so on. If no key was detected, the value is -1.\nRange: -1 - 11',
        'loudness': 'The overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing relative loudness of tracks. Loudness is the quality of a sound that is the primary psychological correlate of physical strength (amplitude). Values typically range between -60 and 0 db.',
        'mode': 'Mode indicates the modality (major or minor) of a track, the type of scale from which its melodic content is derived. Major is represented by 1 and minor is 0.',
        'speechiness': 'Speechiness detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value. Values above 0.66 describe tracks that are probably made entirely of spoken words. Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music. Values below 0.33 most likely represent music and other non-speech-like tracks.',
        'acousticness': 'A confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic.\nRange: 0 - 1\nExample: 0.00242',
        'instrumentalness': 'Predicts whether a track contains no vocals. "Ooh" and "aah" sounds are treated as instrumental in this context. Rap or spoken word tracks are clearly "vocal". The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content. Values above 0.5 are intended to represent instrumental tracks, but confidence is higher as the value approaches 1.0.',
        'liveness': 'Detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live. A value above 0.8 provides strong likelihood that the track is live.',
        'valence': 'A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).\nRange: 0 - 1',
        'tempo': 'The overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration.',
        'duration_ms': 'The duration of the track in milliseconds.',
        'time_signature': 'An estimated time signature. The time signature (meter) is a notational convention to specify how many beats are in each bar (or measure). The time signature ranges from 3 to 7 indicating time signatures of "3/4", to "7/4".\nRange: 3 - 7',
        'duration_mins': 'The duration of the track in minutes:seconds'
    }

    if columna in explicaciones:
        print(f"{colors['cyan']}'{columna}':{colors['reset']} {explicaciones[columna]}")
    else:
        print(f"{colors['red']}No se encontró una explicación para la columna '{columna}'.{colors['reset']}")

# %%
# %%time

df = df_create_top50()
# Out:
# ¿De qué países deseas obtener el TOP 50?
# Inserta 'STOP' cuando hayas acabado
#  es
# 'Spain' agregado a la lista
#  argentina
# 'Argentina' agregado a la lista
#  colombia
# 'Colombia' agregado a la lista
#  peru
# 'Peru' agregado a la lista
#  mexico
# 'Mexico' agregado a la lista
#  portugal
# 'Portugal' agregado a la lista
#  brazil
# 'Brazil' agregado a la lista
#  france
# 'France' agregado a la lista
#  italy
# 'Italy' agregado a la lista
#  germany
# 'Germany' agregado a la lista
#  greece
# 'Greece' agregado a la lista
#  sweeden
# El país 'Sweeden' no está en la lista de países válidos.
# Por favor, intenta de nuevo.
#  sweden
# 'Sweden' agregado a la lista
#  norway
# 'Norway' agregado a la lista
#  au
# 'Australia' agregado a la lista
#  ca
# 'Canada' agregado a la lista
#  egypt
# 'Egypt' agregado a la lista
#  stop
# ['Spain', 'Argentina', 'Colombia', 'Peru', 'Mexico', 'Portugal', 'Brazil', 'France', 'Italy', 'Germany', 'Greece', 'Sweden', 'Norway', 'Australia', 'Canada', 'Egypt']
# -----   TOP 50 de SPAIN     -----
# 1.
# Cancion > BADGYAL
# 2.
# Cancion > Santa
# 3.
# Cancion > ADIVINO
# 4.
# Cancion > X'CLUSIVO - REMIX
# 5.
# Cancion > El Conjuntito
# 6.
# Cancion > Gata Only
# 7.
# Cancion > YO LO SOÑÉ
# 8.
# Cancion > La Vida Sin Ti
# 9.
# Cancion > LUNA
# 10.
# Cancion > LA RANGER (feat. Myke Towers)
# 11.
# Cancion > BBY BOO - REMIX
# 12.
# Cancion > LA SEVILLANA - SEVILLANAS
# 13.
# Cancion > 100xCiento
# 14.
# Cancion > Guay
# 15.
# Cancion > Lo Que Tiene
# 16.
# Cancion > FARDOS
# 17.
# Cancion > LA FALDA
# 18.
# Cancion > CRUSH
# 19.
# Cancion > ESKELETO
# 20.
# Cancion > 1000COSAS
# 21.
# Cancion > Trending Remix (with Myke Towers)
# 22.
# Cancion > Gitana (feat. Bryartz)
# 23.
# Cancion > Martini
# 24.
# Cancion > Diabólica
# 25.
# Cancion > Tengo Un Plan
# 26.
# Cancion > Akureyri
# 27.
# Cancion > La Bachata
# 28.
# Cancion > DESATAAA
# 29.
# Cancion > Manos Rotas
# 30.
# Cancion > Maquillaje
# 31.
# Cancion > El Patio
# 32.
# Cancion > TU$$I (with Dei V)
# 33.
# Cancion > offline
# 34.
# Cancion > La_Original.mp3
# 35.
# Cancion > Un Desperdicio
# 36.
# Cancion > Thalía
# 37.
# Cancion > a new star (2 0 2 4)
# 38.
# Cancion > Columbia
# 39.
# Cancion > MODELITO
# 40.
# Cancion > Beautiful Things
# 41.
# Cancion > COMO SUENAN LAS ESTRELLAS
# 42.
# Cancion > Ride Or Die, Pt. 2 (with Villano Antillano & Tokischa)
# 43.
# Cancion > LA NENA
# 44.
# Cancion > El Merengue
# 45.
# Cancion > SI SI SI SI (feat. Eladio Carrion, Bryant Myers, Dei V)
# 46.
# Cancion > Casanova
# 47.
# Cancion > Una Foto Remix (feat. Emilia)
# 48.
# Cancion > FRIKI
# 49.
# Cancion > Pedro
# 50.
# Cancion > LA CAPI
# -----   TOP 50 de ARGENTINA     -----
# 1.
# Cancion > BESAME (feat. Tiago PZK, Khea & Neo Pistea) - Remix
# 2.
# Cancion > Un Besito Más
# 3.
# Cancion > Piel
# 4.
# Cancion > 30 GRADOS
# 5.
# Cancion > LUNA
# 6.
# Cancion > HOLA PERDIDA
# 7.
# Cancion > Tal Para Cual
# 8.
# Cancion > Santa
# 9.
# Cancion > UH LA LA LA
# 10.
# Cancion > La_Original.mp3
# 11.
# Cancion > Gata Only
# 12.
# Cancion > Ojos Verdes
# 13.
# Cancion > Exclusive.mp3
# 14.
# Cancion > GAFITA Y CHOMBA
# 15.
# Cancion > BBY BOO - REMIX
# 16.
# Cancion > Una Foto Remix (feat. Emilia)
# 17.
# Cancion > Tumba
# 18.
# Cancion > FLECHAZO EN EL CENTRO
# 19.
# Cancion > Mil Preguntas
# 20.
# Cancion > QUE ME FALTE TODO
# 21.
# Cancion > Mil Preguntas
# 22.
# Cancion > offline
# 23.
# Cancion > M.A.I
# 24.
# Cancion > SINVERGÜENZA - con Angela Torres
# 25.
# Cancion > pa
# 26.
# Cancion > FIESTA PUNKY
# 27.
# Cancion > ROZE | DJ TAO Turreo Sessions #22
# 28.
# Cancion > Por Mil Noches
# 29.
# Cancion > Bad Boy
# 30.
# Cancion > Cierre Rkt
# 31.
# Cancion > LATTE (feat. Maria Becerra)
# 32.
# Cancion > buenos aires
# 33.
# Cancion > La Morocha
# 34.
# Cancion > Daytona
# 35.
# Cancion > Sin Querer
# 36.
# Cancion > Inocente
# 37.
# Cancion > EL NEGRO TECLA | Omar Algo Anda Mal #9
# 38.
# Cancion > Una Foto
# 39.
# Cancion > QUE SED
# 40.
# Cancion > Diabólica
# 41.
# Cancion > Ride Or Die, Pt. 2 (with Villano Antillano & Tokischa)
# 42.
# Cancion > Nena Sad
# 43.
# Cancion > Cuarteto Sessions #3
# 44.
# Cancion > El Super Junte Rkt
# 45.
# Cancion > LA FALDA
# 46.
# Cancion > ADIVINO
# 47.
# Cancion > Un Finde | CROSSOVER #2
# 48.
# Cancion > Ese Maldito Momento
# 49.
# Cancion > CORAZÓN VACÍO
# 50.
# Cancion > Ya No Vuelvas (Versión Cuarteto)
# -----   TOP 50 de COLOMBIA     -----
# 1.
# Cancion > LUNA
# 2.
# Cancion > Mirame
# 3.
# Cancion > Brickell
# 4.
# Cancion > Santa
# 5.
# Cancion > PERRO NEGRO
# 6.
# Cancion > offline
# 7.
# Cancion > PUEBLO DE MEDALLO
# 8.
# Cancion > GATA G
# 9.
# Cancion > Ride Or Die, Pt. 2 (with Villano Antillano & Tokischa)
# 10.
# Cancion > AMARGURA
# 11.
# Cancion > SI SABE FERXXO
# 12.
# Cancion > CUAL ES ESA
# 13.
# Cancion > Feliz Cumpleaños Ferxxo
# 14.
# Cancion > QLONA
# 15.
# Cancion > La Diabla
# 16.
# Cancion > ENVIGADO
# 17.
# Cancion > Gata Only
# 18.
# Cancion > ADIVINO
# 19.
# Cancion > La Bachata
# 20.
# Cancion > CLASSY 101
# 21.
# Cancion > ALAKRAN
# 22.
# Cancion > Según Quién
# 23.
# Cancion > QUEMA
# 24.
# Cancion > JORDAN REMIX (feat. Myke Towers)
# 25.
# Cancion > Monastery
# 26.
# Cancion > Normal
# 27.
# Cancion > Una Vida Pasada
# 28.
# Cancion > MI EX TENÍA RAZÓN
# 29.
# Cancion > Es un Secreto
# 30.
# Cancion > GODIVA
# 31.
# Cancion > Primera Cita
# 32.
# Cancion > BBY BOO - REMIX
# 33.
# Cancion > Jordan
# 34.
# Cancion > CHORRITO PA LAS ANIMAS
# 35.
# Cancion > FENDI
# 36.
# Cancion > TU$$I (with Dei V)
# 37.
# Cancion > Ferxxo 100
# 38.
# Cancion > LA RANGER (feat. Myke Towers)
# 39.
# Cancion > MALEANTE (feat. Yandel)
# 40.
# Cancion > Gangsters En La Disco
# 41.
# Cancion > Dile
# 42.
# Cancion > Hey Mor
# 43.
# Cancion > LA INOCENTE
# 44.
# Cancion > Señal De Vida
# 45.
# Cancion > Pa' Que Retozen
# 46.
# Cancion > FRESKI
# 47.
# Cancion > Sicaria
# 48.
# Cancion > NCA
# 49.
# Cancion > Que Onda
# 50.
# Cancion > La Víctima
# -----   TOP 50 de PERU     -----
# 1.
# Cancion > Santa
# 2.
# Cancion > LUNA
# 3.
# Cancion > Gata Only
# 4.
# Cancion > PARTIDO EN DOS
# 5.
# Cancion > Ride Or Die, Pt. 2 (with Villano Antillano & Tokischa)
# 6.
# Cancion > offline
# 7.
# Cancion > AMARGURA
# 8.
# Cancion > Una Vida Pasada
# 9.
# Cancion > PERRO NEGRO
# 10.
# Cancion > La Bachata
# 11.
# Cancion > Una Foto Remix (feat. Emilia)
# 12.
# Cancion > ADIVINO
# 13.
# Cancion > LA FALDA
# 14.
# Cancion > QLONA
# 15.
# Cancion > Piel
# 16.
# Cancion > Feliz Cumpleaños Ferxxo
# 17.
# Cancion > MI EX TENÍA RAZÓN
# 18.
# Cancion > BESAME (feat. Tiago PZK, Khea & Neo Pistea) - Remix
# 19.
# Cancion > BBY BOO - REMIX
# 20.
# Cancion > Rara Vez
# 21.
# Cancion > CLASSY 101
# 22.
# Cancion > LA RANGER (feat. Myke Towers)
# 23.
# Cancion > Según Quién
# 24.
# Cancion > Es un Secreto
# 25.
# Cancion > DILUVIO
# 26.
# Cancion > La Curiosidad
# 27.
# Cancion > Daytona
# 28.
# Cancion > Maquillaje
# 29.
# Cancion > Columbia
# 30.
# Cancion > Desesperados
# 31.
# Cancion > Amanece
# 32.
# Cancion > Brickell
# 33.
# Cancion > Espresso
# 34.
# Cancion > Come back to me
# 35.
# Cancion > Mamichula - con Nicki Nicole
# 36.
# Cancion > Un Finde | CROSSOVER #2
# 37.
# Cancion > Te Pintaron Pajaritos
# 38.
# Cancion > QUÍTENME EL TELÉFONO (feat. Yandel, Jay Wheeler)
# 39.
# Cancion > Si Esta Casa Hablara
# 40.
# Cancion > Borro Cassette
# 41.
# Cancion > LALA
# 42.
# Cancion > M.A.I
# 43.
# Cancion > Normal
# 44.
# Cancion > One Of The Girls (with JENNIE, Lily Rose Depp)
# 45.
# Cancion > OA
# 46.
# Cancion > Cual Adios
# 47.
# Cancion > BELLAKEO
# 48.
# Cancion > Seven (feat. Latto) (Explicit Ver.)
# 49.
# Cancion > i like the way you kiss me
# 50.
# Cancion > La Vida Sin Ti
# -----   TOP 50 de MEXICO     -----
# 1.
# Cancion > Madonna
# 2.
# Cancion > Si No Quieres No
# 3.
# Cancion > Ride Or Die, Pt. 2 (with Villano Antillano & Tokischa)
# 4.
# Cancion > TÚ NAME
# 5.
# Cancion > Corazón de Piedra
# 6.
# Cancion > LA DURANGO
# 7.
# Cancion > 300 Noches
# 8.
# Cancion > Gata Only
# 9.
# Cancion > Natanael Cano: Bzrp Music Sessions, Vol. 59
# 10.
# Cancion > Entre las de 20
# 11.
# Cancion > Regalo De Dios
# 12.
# Cancion > Elvira
# 13.
# Cancion > La Diabla
# 14.
# Cancion > Un Desperdicio
# 15.
# Cancion > Que Onda
# 16.
# Cancion > El Boss
# 17.
# Cancion > LA PEOPLE II
# 18.
# Cancion > GTA
# 19.
# Cancion > Y LLORO
# 20.
# Cancion > La Víctima
# 21.
# Cancion > Santa
# 22.
# Cancion > ROCKSTAR
# 23.
# Cancion > Lo Tienes Todo
# 24.
# Cancion > Que Se Cuide
# 25.
# Cancion > CRAZYZ
# 26.
# Cancion > LUNA
# 27.
# Cancion > ADIVINO
# 28.
# Cancion > UNA CERVEZA
# 29.
# Cancion > SABOR FRESA
# 30.
# Cancion > EL AMOR DE SU VIDA
# 31.
# Cancion > O Me Voy O Te Vas
# 32.
# Cancion > Dime
# 33.
# Cancion > FIRST LOVE
# 34.
# Cancion > Ch y la Pizza
# 35.
# Cancion > Primera Cita
# 36.
# Cancion > HARLEY QUINN
# 37.
# Cancion > La Guerita
# 38.
# Cancion > QLONA
# 39.
# Cancion > Mi Bello Angel
# 40.
# Cancion > LADY GAGA
# 41.
# Cancion > Pongámonos De Acuerdo
# 42.
# Cancion > Vete
# 43.
# Cancion > A Puro Dolor
# 44.
# Cancion > Apaga El Cel
# 45.
# Cancion > Según Quién
# 46.
# Cancion > Brillarosa
# 47.
# Cancion > ELOVRGA
# 48.
# Cancion > Poco A Poco
# 49.
# Cancion > Don Dimadon
# 50.
# Cancion > Igual Que Un Ángel (with Peso Pluma)
# -----   TOP 50 de PORTUGAL     -----
# 1.
# Cancion > Bênção
# 2.
# Cancion > Não Vou Namorar
# 3.
# Cancion > Not Like Us
# 4.
# Cancion > Alô
# 5.
# Cancion > Beautiful Things
# 6.
# Cancion > Tata
# 7.
# Cancion > Gata Only
# 8.
# Cancion > Espresso
# 9.
# Cancion > Problemas de um Milionário
# 10.
# Cancion > Samba de Malandro
# 11.
# Cancion > Habibi
# 12.
# Cancion > jingle.tm - remix
# 13.
# Cancion > Qual é seu desejo?
# 14.
# Cancion > CONFISSÕES PT2
# 15.
# Cancion > Lose Control
# 16.
# Cancion > i like the way you kiss me
# 17.
# Cancion > Aquariano Nato
# 18.
# Cancion > Too Sweet
# 19.
# Cancion > Fortnight (feat. Post Malone)
# 20.
# Cancion > Alma Nua
# 21.
# Cancion > euphoria
# 22.
# Cancion > Nois é Nois
# 23.
# Cancion > POCPOC
# 24.
# Cancion > MILLION DOLLAR BABY
# 25.
# Cancion > A Internet É Toxica
# 26.
# Cancion > Carro (feat. Dillaz)
# 27.
# Cancion > Mtg Quero Te Encontrar
# 28.
# Cancion > Nota 100
# 29.
# Cancion > De 10 Mulher 11 É Maluca
# 30.
# Cancion > Chamadas
# 31.
# Cancion > End of Beginning
# 32.
# Cancion > Si No Estás
# 33.
# Cancion > Amar De Cor
# 34.
# Cancion > Faz Bem
# 35.
# Cancion > Mo Boy
# 36.
# Cancion > Vem Desestressar
# 37.
# Cancion > Filho da Noite
# 38.
# Cancion > SEYA
# 39.
# Cancion > Brutos Diamantes
# 40.
# Cancion > Rolé na Favela de Nave
# 41.
# Cancion > Sem Ti
# 42.
# Cancion > Tropa do Flamengo
# 43.
# Cancion > I Can Do It With a Broken Heart
# 44.
# Cancion > Chakras
# 45.
# Cancion > we can't be friends (wait for your love)
# 46.
# Cancion > Casca de Bala
# 47.
# Cancion > Tenho Que Me Decidir
# 48.
# Cancion > Pedro
# 49.
# Cancion > Colãs
# 50.
# Cancion > I Had Some Help (Feat. Morgan Wallen)
# -----   TOP 50 de BRAZIL     -----
# 1.
# Cancion > Digitando
# 2.
# Cancion > Mtg Quero Te Encontrar
# 3.
# Cancion > THE BOX MEDLEY FUNK 2
# 4.
# Cancion > Não Vou Namorar
# 5.
# Cancion > Gosta De Rua - Ao Vivo
# 6.
# Cancion > ENTRA NA DEFENDER
# 7.
# Cancion > CONFISSÕES PT2
# 8.
# Cancion > Deu Moral - Ao Vivo
# 9.
# Cancion > Dois Tristes - Ao Vivo
# 10.
# Cancion > Haverá Sinais - Ao Vivo
# 11.
# Cancion > Foi Intenso - Ao Vivo
# 12.
# Cancion > Vamo Marolar
# 13.
# Cancion > Aquariano Nato
# 14.
# Cancion > Filho da Noite
# 15.
# Cancion > Morena De Goiânia - Ao Vivo
# 16.
# Cancion > Não Recomendo - Ao Vivo
# 17.
# Cancion > Barulho Do Foguete - Ao Vivo
# 18.
# Cancion > Vazou Na Braquiara - Ao Vivo
# 19.
# Cancion > Samba de Malandro
# 20.
# Cancion > Casca de Bala
# 21.
# Cancion > TUMBÁTUM
# 22.
# Cancion > Anestesiado - Ao Vivo
# 23.
# Cancion > Diz Aí Qual é o Plano?
# 24.
# Cancion > Dedo do Meio - Ao Vivo
# 25.
# Cancion > Lua
# 26.
# Cancion > A Internet É Toxica
# 27.
# Cancion > Melhor Vibe
# 28.
# Cancion > Problemas de um Milionário
# 29.
# Cancion > Mtg Forró e Desmantelo
# 30.
# Cancion > PEGA ESCANDALOSO
# 31.
# Cancion > Maravilhosa - Ao Vivo
# 32.
# Cancion > Quase Algo - Ao Vivo Em Nova Iorque / 2022
# 33.
# Cancion > Vem Desestressar
# 34.
# Cancion > De 10 Mulher 11 É Maluca
# 35.
# Cancion > Daqui pra Sempre
# 36.
# Cancion > Dia de Fluxo
# 37.
# Cancion > RAM TCHUM
# 38.
# Cancion > Qual é seu desejo?
# 39.
# Cancion > Me Leva Pra Casa / Escrito Nas Estrelas / Saudade - Ao Vivo
# 40.
# Cancion > Amor Na Praia
# 41.
# Cancion > Dois Fugitivos - Ao Vivo
# 42.
# Cancion > Fronteira - Ao Vivo
# 43.
# Cancion > Torre Eiffel - Ao Vivo
# 44.
# Cancion > Let's Go 4
# 45.
# Cancion > A Cerveja Abre Sozinha - Ao Vivo
# 46.
# Cancion > Baby Eu Tava na Rua da Água
# 47.
# Cancion > Passada de Mão - Ao Vivo
# 48.
# Cancion > Too Sweet
# 49.
# Cancion > Beautiful Things
# 50.
# Cancion > Rolé na Favela de Nave
# -----   TOP 50 de FRANCE     -----
# 1.
# Cancion > Imagine
# 2.
# Cancion > Position
# 3.
# Cancion > Boucan (feat. Franglish)
# 4.
# Cancion > Gata Only
# 5.
# Cancion > Petit génie
# 6.
# Cancion > MAMI WATA
# 7.
# Cancion > Oh qu'elle est belle
# 8.
# Cancion > Beautiful Things
# 9.
# Cancion > The Sound of Silence - CYRIL Remix
# 10.
# Cancion > Aucune attache
# 11.
# Cancion > Ceux qu'on était
# 12.
# Cancion > Temps en temps
# 13.
# Cancion > i like the way you kiss me
# 14.
# Cancion > Lose Control
# 15.
# Cancion > I love you
# 16.
# Cancion > Tu connais
# 17.
# Cancion > Stumblin' In
# 18.
# Cancion > Michael Jordan
# 19.
# Cancion > Si No Estás
# 20.
# Cancion > Casanova
# 21.
# Cancion > Faut pas
# 22.
# Cancion > Espresso
# 23.
# Cancion > Mélanine
# 24.
# Cancion > Laboratoire
# 25.
# Cancion > Dolce Camara
# 26.
# Cancion > Fortnight (feat. Post Malone)
# 27.
# Cancion > TEXAS HOLD 'EM
# 28.
# Cancion > Pyramide
# 29.
# Cancion > Maudit
# 30.
# Cancion > LOCO
# 31.
# Cancion > I Don't Wanna Wait
# 32.
# Cancion > Saison 2
# 33.
# Cancion > Training Season
# 34.
# Cancion > Quillé
# 35.
# Cancion > Bottega
# 36.
# Cancion > GARS DU ZOO
# 37.
# Cancion > FLASHBACK
# 38.
# Cancion > Bolide allemand
# 39.
# Cancion > Avec classe (feat. Aya Nakamura & Trinix)
# 40.
# Cancion > Houdini
# 41.
# Cancion > Overdrive (feat. Norma Jean Martine)
# 42.
# Cancion > Wayeh
# 43.
# Cancion > La symphonie des éclairs
# 44.
# Cancion > Mon amour
# 45.
# Cancion > barcelona92
# 46.
# Cancion > Whatever
# 47.
# Cancion > X
# 48.
# Cancion > Ça mène à rien
# 49.
# Cancion > Too Sweet
# 50.
# Cancion > SPIDER
# -----   TOP 50 de ITALY     -----
# 1.
# Cancion > BBE (feat. Lazza)
# 2.
# Cancion > COME UN TUONO (feat. Guè)
# 3.
# Cancion > 100 MESSAGGI
# 4.
# Cancion > MIU MIU
# 5.
# Cancion > Gata Only
# 6.
# Cancion > L'ULTIMA POESIA
# 7.
# Cancion > EL PIBE DE ORO
# 8.
# Cancion > DOPO LE 4 (feat. Bresh & Tedua)
# 9.
# Cancion > Soldi Arrotolati (feat. ANNA)
# 10.
# Cancion > Money Rain (feat. Lazza)
# 11.
# Cancion > Ancora Qua (feat. Tedua)
# 12.
# Cancion > Devastante
# 13.
# Cancion > ALTROVE
# 14.
# Cancion > Paprika
# 15.
# Cancion > I P’ ME, TU P’ TE
# 16.
# Cancion > 00
# 17.
# Cancion > TUTA GOLD
# 18.
# Cancion > Torcida
# 19.
# Cancion > Sola (feat. Lazza, Tedua)
# 20.
# Cancion > la noia
# 21.
# Cancion > CLICK BOOM!
# 22.
# Cancion > Acqua Passata
# 23.
# Cancion > Eva (feat. Tedua)
# 24.
# Cancion > I CAN FLY
# 25.
# Cancion > Sinceramente
# 26.
# Cancion > VIENI DALLA BADDIE - interlude
# 27.
# Cancion > i like the way you kiss me
# 28.
# Cancion > Adrenalina (feat. BLANCO, Marracash)
# 29.
# Cancion > ADDO STAJE - Ride it RMX
# 30.
# Cancion > Sottovuoto
# 31.
# Cancion > Madame (feat. Sfera Ebbasta)
# 32.
# Cancion > Ferite
# 33.
# Cancion > Istinto Animale (feat. Guè, Annalisa, Ernia)
# 34.
# Cancion > ICON
# 35.
# Cancion > EL MATADOR (From the Netflix Rap Show “Nuova Scena”)
# 36.
# Cancion > MA CHE IDEA (feat. Pino D'Angiò)
# 37.
# Cancion > SCUSI MAESTRA (feat. Tedua)
# 38.
# Cancion > Alé (feat. Capo Plaza)
# 39.
# Cancion > Vai!
# 40.
# Cancion > Beautiful Things
# 41.
# Cancion > I Miss U (feat. Tony Boy)
# 42.
# Cancion > Casa Mia
# 43.
# Cancion > VELENO
# 44.
# Cancion > APNEA
# 45.
# Cancion > Not Like Us
# 46.
# Cancion > Anche Stasera
# 47.
# Cancion > LUCIA (STAY WITH ME)
# 48.
# Cancion > Memories (feat. Annalisa)
# 49.
# Cancion > Petit Fou Fou (feat. ANNA)
# 50.
# Cancion > PILLOLE (feat. Sfera Ebbasta & Geolier)
# -----   TOP 50 de GERMANY     -----
# 1.
# Cancion > Wunder
# 2.
# Cancion > i like the way you kiss me
# 3.
# Cancion > Gata Only
# 4.
# Cancion > UR IN MY HEAD
# 5.
# Cancion > VEMPA
# 6.
# Cancion > Pedro
# 7.
# Cancion > Pistoleta
# 8.
# Cancion > Cabrio
# 9.
# Cancion > ZEIT, DASS SICH WAS DREHT
# 10.
# Cancion > Belong Together
# 11.
# Cancion > Mama hat gesagt
# 12.
# Cancion > MILLION DOLLAR BABY
# 13.
# Cancion > Beautiful Things
# 14.
# Cancion > Stumblin' In
# 15.
# Cancion > nimm mit
# 16.
# Cancion > I Had Some Help (Feat. Morgan Wallen)
# 17.
# Cancion > Pa Mu
# 18.
# Cancion > Vois sur ton chemin - Techno Mix
# 19.
# Cancion > Amo aller Amos
# 20.
# Cancion > Alkohol - #40Bochum
# 21.
# Cancion > Not Like Us
# 22.
# Cancion > Espresso
# 23.
# Cancion > Lithe Fall Back
# 24.
# Cancion > Erwischt
# 25.
# Cancion > Too Sweet
# 26.
# Cancion > A Bar Song (Tipsy)
# 27.
# Cancion > Thank You (Not So Bad)
# 28.
# Cancion > Prada
# 29.
# Cancion > Balla Balla
# 30.
# Cancion > BLICKYS
# 31.
# Cancion > Fortnight (feat. Post Malone)
# 32.
# Cancion > Do you lie
# 33.
# Cancion > Madness & Badness
# 34.
# Cancion > PANAMERA
# 35.
# Cancion > Lose Control
# 36.
# Cancion > Toast 🍸
# 37.
# Cancion > So So Def (feat. Summer Cem & Nimo)
# 38.
# Cancion > Vorbei
# 39.
# Cancion > LET'S GET FKD UP
# 40.
# Cancion > Austin
# 41.
# Cancion > TEXAS HOLD 'EM
# 42.
# Cancion > 3 Worte
# 43.
# Cancion > End of Beginning
# 44.
# Cancion > Substanzen (feat. Aymen, Jiyo & ilo 7araga)
# 45.
# Cancion > Unwritten
# 46.
# Cancion > Eurosport
# 47.
# Cancion > Another Vibe (feat. Omah Lay)
# 48.
# Cancion > Mwaki
# 49.
# Cancion > GOLF R FREESTYLE
# 50.
# Cancion > Vielleicht Vielleicht
# -----   TOP 50 de GREECE     -----
# 1.
# Cancion > ZARI
# 2.
# Cancion > MBAPPE
# 3.
# Cancion > Messy
# 4.
# Cancion > 9ARI
# 5.
# Cancion > Dokimasia
# 6.
# Cancion > Parapatao
# 7.
# Cancion > San Emas
# 8.
# Cancion > Drugs N Bass
# 9.
# Cancion > 0-100
# 10.
# Cancion > 1+1
# 11.
# Cancion > Siga To Prama
# 12.
# Cancion > Terrano
# 13.
# Cancion > Taxidi
# 14.
# Cancion > Apotoma
# 15.
# Cancion > Homesick
# 16.
# Cancion > KSIRASIA
# 17.
# Cancion > Mad 4 Ever - Outro
# 18.
# Cancion > MILLION
# 19.
# Cancion > RATATA
# 20.
# Cancion > Allou
# 21.
# Cancion > Eipes
# 22.
# Cancion > Ganador 2 - Intro
# 23.
# Cancion > Panselinos
# 24.
# Cancion > Epal
# 25.
# Cancion > Arga
# 26.
# Cancion > Rap Game Dead
# 27.
# Cancion > ROLLS ROYCE
# 28.
# Cancion > Amarties
# 29.
# Cancion > Sukarie
# 30.
# Cancion > PRIN MAFISEIS
# 31.
# Cancion > Allegra (N1)
# 32.
# Cancion > Not Like Us
# 33.
# Cancion > Death Before Dishonor
# 34.
# Cancion > Miami
# 35.
# Cancion > 3:15
# 36.
# Cancion > Ethismos
# 37.
# Cancion > Psyfunk
# 38.
# Cancion > XILIOMETRA
# 39.
# Cancion > The Code
# 40.
# Cancion > 1000 Xiliometra - Bonus Track
# 41.
# Cancion > ISOS
# 42.
# Cancion > Blu
# 43.
# Cancion > Iremia
# 44.
# Cancion > Gata Only
# 45.
# Cancion > ANASAINO KAI ZALIZOMAI
# 46.
# Cancion > Magia
# 47.
# Cancion > Skoni
# 48.
# Cancion > THE DEAL
# 49.
# Cancion > Houston
# 50.
# Cancion > la noia
# -----   TOP 50 de SWEDEN     -----
# 1.
# Cancion > A Bar Song (Tipsy)
# 2.
# Cancion > I Had Some Help (Feat. Morgan Wallen)
# 3.
# Cancion > Honey Boy (feat. Nile Rodgers & Shenseea)
# 4.
# Cancion > Helluva life
# 5.
# Cancion > VEM FAN E DU?
# 6.
# Cancion > i like the way you kiss me
# 7.
# Cancion > Maraton (feat. Eah Jé)
# 8.
# Cancion > HEMSK
# 9.
# Cancion > Jag önskar jag brydde mig mer
# 10.
# Cancion > Välkommen ner
# 11.
# Cancion > Unforgettable
# 12.
# Cancion > Espresso
# 13.
# Cancion > Too Sweet
# 14.
# Cancion > EN GÅNG TILL
# 15.
# Cancion > Not Like Us
# 16.
# Cancion > Que Sera
# 17.
# Cancion > Belong Together
# 18.
# Cancion > Hej du
# 19.
# Cancion > Beautiful Things
# 20.
# Cancion > Hålla mig
# 21.
# Cancion > Bærum Bitches (Mannschaft)
# 22.
# Cancion > Kite
# 23.
# Cancion > Better Days
# 24.
# Cancion > Europapa
# 25.
# Cancion > Pedro
# 26.
# Cancion > Fortnight (feat. Post Malone)
# 27.
# Cancion > MILLION DOLLAR BABY
# 28.
# Cancion > DECIBEL
# 29.
# Cancion > Sangenjaya 3am
# 30.
# Cancion > Ica
# 31.
# Cancion > Låt Mig Va
# 32.
# Cancion > Dig (Ormingevisan)
# 33.
# Cancion > Misstag
# 34.
# Cancion > Austin
# 35.
# Cancion > Okej att dö
# 36.
# Cancion > Rim Tim Tagi Dim
# 37.
# Cancion > Lose Control
# 38.
# Cancion > TEXAS HOLD 'EM
# 39.
# Cancion > Djurens vaggvisa
# 40.
# Cancion > Ikväll Igen
# 41.
# Cancion > Väck mig när det är över
# 42.
# Cancion > Lilla B
# 43.
# Cancion > Sunnanvind
# 44.
# Cancion > Gata Only
# 45.
# Cancion > Whatever
# 46.
# Cancion > En sån som mig
# 47.
# Cancion > Babblarnas vaggvisa
# 48.
# Cancion > Hundra lax kärlek
# 49.
# Cancion > Thank You (Not So Bad)
# 50.
# Cancion > Prada
# -----   TOP 50 de NORWAY     -----
# 1.
# Cancion > I Had Some Help (Feat. Morgan Wallen)
# 2.
# Cancion > A Bar Song (Tipsy)
# 3.
# Cancion > Espresso
# 4.
# Cancion > Too Sweet
# 5.
# Cancion > Bærum Bitches (Mannschaft)
# 6.
# Cancion > Belong Together
# 7.
# Cancion > Not Like Us
# 8.
# Cancion > SOLDAT - RMX
# 9.
# Cancion > Beautiful Things
# 10.
# Cancion > MILLION DOLLAR BABY
# 11.
# Cancion > Sølvskje
# 12.
# Cancion > i like the way you kiss me
# 13.
# Cancion > Feite Damer (The Broject)
# 14.
# Cancion > Tenke Sjæl
# 15.
# Cancion > Austin
# 16.
# Cancion > Dans Med Meg
# 17.
# Cancion > Pedro
# 18.
# Cancion > Volare
# 19.
# Cancion > Lose Control
# 20.
# Cancion > we can't be friends (wait for your love)
# 21.
# Cancion > Situasjon
# 22.
# Cancion > Da vi var to
# 23.
# Cancion > Roc Boyz Freestyle
# 24.
# Cancion > baby
# 25.
# Cancion > The Sound of Silence - CYRIL Remix
# 26.
# Cancion > Whatever
# 27.
# Cancion > Badebussen (feat. Kjartan Lauritzen)
# 28.
# Cancion > Before You Leave Me
# 29.
# Cancion > Stargazing
# 30.
# Cancion > Superhelt Steez
# 31.
# Cancion > Slow It Down
# 32.
# Cancion > Fortnight (feat. Post Malone)
# 33.
# Cancion > hva om jeg slutta å bry meg
# 34.
# Cancion > Rockstar lie
# 35.
# Cancion > FOREVIG (med TIX)
# 36.
# Cancion > I Don't Wanna Wait
# 37.
# Cancion > Casino
# 38.
# Cancion > TEXAS HOLD 'EM
# 39.
# Cancion > For Life (feat. Nile Rodgers)
# 40.
# Cancion > Scared To Start
# 41.
# Cancion > End of Beginning
# 42.
# Cancion > euphoria
# 43.
# Cancion > Unforgettable
# 44.
# Cancion > Working
# 45.
# Cancion > Gata Only
# 46.
# Cancion > Prada
# 47.
# Cancion > Schnogodidougudugidoubudibow
# 48.
# Cancion > Tell Ur Girlfriend
# 49.
# Cancion > Europapa
# 50.
# Cancion > Like That
# -----   TOP 50 de AUSTRALIA     -----
# 1.
# Cancion > I Had Some Help (Feat. Morgan Wallen)
# 2.
# Cancion > MILLION DOLLAR BABY
# 3.
# Cancion > A Bar Song (Tipsy)
# 4.
# Cancion > Espresso
# 5.
# Cancion > Not Like Us
# 6.
# Cancion > Fortnight (feat. Post Malone)
# 7.
# Cancion > Beautiful Things
# 8.
# Cancion > Too Sweet
# 9.
# Cancion > i like the way you kiss me
# 10.
# Cancion > Stick Season
# 11.
# Cancion > I Can Do It With a Broken Heart
# 12.
# Cancion > euphoria
# 13.
# Cancion > Lose Control
# 14.
# Cancion > Austin
# 15.
# Cancion > Belong Together
# 16.
# Cancion > End of Beginning
# 17.
# Cancion > Down Bad
# 18.
# Cancion > we can't be friends (wait for your love)
# 19.
# Cancion > Like That
# 20.
# Cancion > I Remember Everything (feat. Kacey Musgraves)
# 21.
# Cancion > Scared To Start
# 22.
# Cancion > Who’s Afraid of Little Old Me?
# 23.
# Cancion > Saturn
# 24.
# Cancion > Slow It Down
# 25.
# Cancion > So Long, London
# 26.
# Cancion > Tell Ur Girlfriend
# 27.
# Cancion > Cruel Summer
# 28.
# Cancion > greedy
# 29.
# Cancion > But Daddy I Love Him
# 30.
# Cancion > Lovin On Me
# 31.
# Cancion > Something in the Orange
# 32.
# Cancion > Last Night
# 33.
# Cancion > My Boy Only Breaks His Favorite Toys
# 34.
# Cancion > Guilty as Sin?
# 35.
# Cancion > Florida!!! (feat. Florence + The Machine)
# 36.
# Cancion > Family Matters
# 37.
# Cancion > Stumblin' In
# 38.
# Cancion > The Tortured Poets Department
# 39.
# Cancion > Prada
# 40.
# Cancion > Riptide
# 41.
# Cancion > Thinkin’ Bout Me
# 42.
# Cancion > meet the grahams
# 43.
# Cancion > Good Luck, Babe!
# 44.
# Cancion > The Smallest Man Who Ever Lived
# 45.
# Cancion > TEXAS HOLD 'EM
# 46.
# Cancion > Push Ups
# 47.
# Cancion > Home
# 48.
# Cancion > All The Stars (with SZA)
# 49.
# Cancion > Stargazing
# 50.
# Cancion > As It Was
# -----   TOP 50 de CANADA     -----
# 1.
# Cancion > I Had Some Help (Feat. Morgan Wallen)
# 2.
# Cancion > A Bar Song (Tipsy)
# 3.
# Cancion > Not Like Us
# 4.
# Cancion > MILLION DOLLAR BABY
# 5.
# Cancion > Espresso
# 6.
# Cancion > Beautiful Things
# 7.
# Cancion > euphoria
# 8.
# Cancion > Fortnight (feat. Post Malone)
# 9.
# Cancion > Too Sweet
# 10.
# Cancion > Family Matters
# 11.
# Cancion > Like That
# 12.
# Cancion > I Can Do It With a Broken Heart
# 13.
# Cancion > Stick Season
# 14.
# Cancion > i like the way you kiss me
# 15.
# Cancion > Belong Together
# 16.
# Cancion > Lose Control
# 17.
# Cancion > I Remember Everything (feat. Kacey Musgraves)
# 18.
# Cancion > Austin
# 19.
# Cancion > Slow It Down
# 20.
# Cancion > Stargazing
# 21.
# Cancion > Down Bad
# 22.
# Cancion > Last Night
# 23.
# Cancion > we can't be friends (wait for your love)
# 24.
# Cancion > Push Ups
# 25.
# Cancion > meet the grahams
# 26.
# Cancion > Miles On It
# 27.
# Cancion > Scared To Start
# 28.
# Cancion > Who’s Afraid of Little Old Me?
# 29.
# Cancion > Thinkin’ Bout Me
# 30.
# Cancion > End of Beginning
# 31.
# Cancion > Good Luck, Babe!
# 32.
# Cancion > Something in the Orange
# 33.
# Cancion > Saturn
# 34.
# Cancion > So Long, London
# 35.
# Cancion > Gata Only
# 36.
# Cancion > But Daddy I Love Him
# 37.
# Cancion > Type Shit
# 38.
# Cancion > Guilty as Sin?
# 39.
# Cancion > CARNIVAL
# 40.
# Cancion > FE!N (feat. Playboi Carti)
# 41.
# Cancion > Florida!!! (feat. Florence + The Machine)
# 42.
# Cancion > greedy
# 43.
# Cancion > You Proof
# 44.
# Cancion > My Boy Only Breaks His Favorite Toys
# 45.
# Cancion > Fast Car
# 46.
# Cancion > Lovin On Me
# 47.
# Cancion > Tell Ur Girlfriend
# 48.
# Cancion > Cowgirls (feat. ERNEST)
# 49.
# Cancion > Dial Drunk (with Post Malone)
# 50.
# Cancion > TEXAS HOLD 'EM
# -----   TOP 50 de EGYPT     -----
# 1.
# Cancion > اتنين بمقام ملايين
# 2.
# Cancion > قمبلة الجيل ( اختي وصحبتي )
# 3.
# Cancion > بيكلموني
# 4.
# Cancion > زماني صابني عيار
# 5.
# Cancion > ايويا يا حبيبتي وحشتيني
# 6.
# Cancion > من فضل الاخصام خفو التخطير ( انا مش ع الدواق )
# 7.
# Cancion > عالعموم
# 8.
# Cancion > اكشن جاي اتعارك - عيني جت علي سنيورة
# 9.
# Cancion > PARIS
# 10.
# Cancion > هنط جامب بالاوكابي
# 11.
# Cancion > El Mabda2
# 12.
# Cancion > سيبك من اللي خلع - من فيلم حمص وحلاوة
# 13.
# Cancion > جيت متأخر
# 14.
# Cancion > هيجيلي موجوع
# 15.
# Cancion > Matafetch
# 16.
# Cancion > YAZMEELY
# 17.
# Cancion > Khaleny Fe Hodnak
# 18.
# Cancion > البخت
# 19.
# Cancion > منحرفين ( في حضورنا الدنيا بتتشقلب )
# 20.
# Cancion > اللي نفسه فيا بيتي ميتوهش
# 21.
# Cancion > انتي فاكره نفسك ايه ؟
# 22.
# Cancion > وغلاوتك
# 23.
# Cancion > يمكن خير
# 24.
# Cancion > سيبك من كرته المواقع ( خد كشاف انا عارف انك ياض بتخاف )
# 25.
# Cancion > ظروف معنداني
# 26.
# Cancion > اختياراتي - من فيلم مستر إكس
# 27.
# Cancion > لما بيوحشني
# 28.
# Cancion > كلها بقا ليها اخصام - عليا الطلاق كله بيكدب
# 29.
# Cancion > غيرك حاول
# 30.
# Cancion > Tegy Ntrahn
# 31.
# Cancion > لفينا الدنيا
# 32.
# Cancion > Fouq
# 33.
# Cancion > El Dalaa
# 34.
# Cancion > Reyah El Hayah
# 35.
# Cancion > لحظة بعادك
# 36.
# Cancion > طب هأ دي حبيبتك مش بتقول لا - مهرجان - طب هأ دي حبيبتك مش بتقول لا - اسلام كابونجا -ميسو ميسره -توزيع فيجو الدخلاوي مهرجانات
# 37.
# Cancion > Basrah w Atooh
# 38.
# Cancion > Not Like Us
# 39.
# Cancion > Mesh Nadman
# 40.
# Cancion > كلام عينيه
# 41.
# Cancion > Rehla
# 42.
# Cancion > Kan Mawdo3
# 43.
# Cancion > مهرجان بنكش علي شغله - واقف علي الامه - خصمي ده جالي جهتي
# 44.
# Cancion > و افتكرت
# 45.
# Cancion > 3ereft Eimtek
# 46.
# Cancion > Aleb Fel Dafater
# 47.
# Cancion > لِلّي
# 48.
# Cancion > Alo Aleky
# 49.
# Cancion > التزموا الصمت اسود الارض راجعين ( يابا احنا نغيب غيبتنا )
# 50.
# Cancion > Hayaty Msh Tamam
# CPU times: total: 1min 23s
# Wall time: 9min 52s

# %% [markdown]
# ## Creacion del DataFrame - Top10 por Generos
# ### df_create_top_genres()

# %%
def top_artist_by_genre(genre):
    """
    Busca los mejores artistas de un género específico utilizando la API de Spotify.
    Args:
        genre (str): El género musical para el cual se buscarán los mejores artistas.
    Returns:
        DataFrame or None: Un DataFrame que contiene información sobre los mejores artistas encontrados o None si ocurrió un error.
    """
    response = get_artist_by_genre(genre)

    if response.status_code == 200:
        data = response.json()
        top10_dict = {}
        top10_dict['artists_top10'] = []
        top10_dict['followers_top10'] = []
        top10_dict['position_top10'] = []
        top10_dict['hrefs'] = []
        for i, subdata in enumerate(data['artists']['items']):
            for j in range(10):
                top10_dict['artists_top10'].append(subdata['name'])
                top10_dict['followers_top10'].append(subdata['followers']['total'])
                top10_dict['position_top10'].append(i + 1)
                href = subdata['href']
                top10_dict['hrefs'].append(href)
                artist_new_data = get_artist_top10_tracks_features(href)
                for k, info in enumerate(artist_new_data):
                    print(info)
                    top10_dict['track_position'] = j + 1
                    top10_dict['track_name'] = info['name']
                    top10_dict['track_id'] = info['id']
                    top10_dict['album'] = info['album']['name']
                    top10_dict['release_date'] = info['album']['release_date']            
        
        df = pd.DataFrame(top10_dict)
        return df
    else:
        print(f'Error al buscar artistas: {response.status_code}')
        return None

# %%
def ask_genres():
    generos_musicales = [
        "Pop",
        "Rock",
        "Hip-Hop/Rap",
        "Electrónica/Dance",
        "Reggae",
        "Country",
        "Jazz",
        "Clásica",
        "R&B/Soul",
        "Indie",
        "Folk",
        "Reguetón",
        "Metal",
        "Blues",
        "Punk",
        "Funk",
        "Ska",
        "Gospel",
        "Dubstep",
        "Ambient"
    ]
    
    genres = []
    while True:
        genre = input("Ingresa un género musical (o 'fin' para terminar): ").strip().capitalize()
        if genre == 'Fin':
            break
        elif genre in generos_musicales:
            genres.append(genre)
        else:
            print(f"El género '{genre}' no es válido. Por favor, intenta nuevamente.")
    
    return genres

# %%
def get_top10_data():
    genres = ask_genres()
    
    
    top10_dict = {
            'genre': [],
            'artists_top10': [],
            'followers_top10': [],
            'position_top10': [],
            'track_position': [],
            'track_name': [],
            'id': [],
            'album': [],
            'release_date': []
    }
    
    all_tracks_info = []    

    for genre in genres:
        print(genre)
        response = get_artist_by_genre(genre)
        if response.status_code == 200:
            data = response.json()
        for i, subdata in enumerate(data['artists']['items']):
            href = subdata['href']
            artist_new_data = get_artist_top10_tracks_features(href)
            for j, info in enumerate(artist_new_data['tracks']):
                top10_dict['genre'].append(genre)
                artist = subdata['name']
                top10_dict['artists_top10'].append(artist)
                followers = subdata['followers']['total']
                top10_dict['followers_top10'].append(followers)
                pos_top10 = i + 1
                top10_dict['position_top10'].append(pos_top10)
                track_pos = j + 1
                top10_dict['track_position'].append(track_pos)
                track_name = info['name']
                top10_dict['track_name'].append(track_name)
                track_id = info['id']
                top10_dict['id'].append(track_id)
                album = info['album']['name']
                top10_dict['album'].append(album)
                rel_date = info['album']['release_date']
                top10_dict['release_date'].append(rel_date)
                all_tracks_info.append(get_track_feature(track_id))
    df1 = pd.DataFrame(top10_dict)
    df2 = pd.DataFrame(all_tracks_info)
    merged_df = pd.merge(df1, df2, on='id', how='left')
    directory = "./df_unprocessed/"
    if not os.path.exists(directory):
        os.makedirs(directory)
    merged_df.to_pickle("./df_unprocessed/df_top10_unprocessed.pkl")
    return merged_df

# %%
# %%time

df2 = get_top10_data()
# Out:
# Ingresa un género musical (o 'fin' para terminar):  pop
# Ingresa un género musical (o 'fin' para terminar):  rock
# Ingresa un género musical (o 'fin' para terminar):  metal
# Ingresa un género musical (o 'fin' para terminar):  indie
# Ingresa un género musical (o 'fin' para terminar):  blues
# Ingresa un género musical (o 'fin' para terminar):  jazz
# Ingresa un género musical (o 'fin' para terminar):  ambient
# Ingresa un género musical (o 'fin' para terminar):  country
# Ingresa un género musical (o 'fin' para terminar):  dubstep
# Ingresa un género musical (o 'fin' para terminar):  fin
# Pop
# Rock
# Metal
# Indie
# Blues
# Jazz
# Ambient
# Country
# Dubstep
# CPU times: total: 46.2 s
# Wall time: 5min 17s

# %%
df2
# Out:
#         genre artists_top10  followers_top10  position_top10  track_position  \
# 0         Pop  Taylor Swift        109763338               1               1
# 1         Pop  Taylor Swift        109763338               1               1
# 2         Pop  Taylor Swift        109763338               1               2
# 3         Pop  Taylor Swift        109763338               1               3
# 4         Pop  Taylor Swift        109763338               1               4
# ...       ...           ...              ...             ...             ...
# 1105  Dubstep  SVDDEN DEATH           223166              10               6
# 1106  Dubstep  SVDDEN DEATH           223166              10               7
# 1107  Dubstep  SVDDEN DEATH           223166              10               8
# 1108  Dubstep  SVDDEN DEATH           223166              10               9
# 1109  Dubstep  SVDDEN DEATH           223166              10              10
#
#                            track_name                      id  \
# 0       Fortnight (feat. Post Malone)  2OzhQlSqBEmt7hmkYxfT6m
# 1       Fortnight (feat. Post Malone)  2OzhQlSqBEmt7hmkYxfT6m
# 2     I Can Do It With a Broken Heart  4q5YezDOIPcoLr8R81x9qy
# 3                            Down Bad  2F3N9tdombb64aW6VtZOdo
# 4                        Cruel Summer  1BxfuPKGuaTgP7aM0Bbdwr
# ...                               ...                     ...
# 1105                     Behemoth VIP  0tkwUKjhuBA5UuA95JY2bU
# 1106                         Behemoth  4o7Rszx7VVCzrCr1RPlPot
# 1107                     Burn It Down  7q8P4LHGckqsQt4uFnUQ5N
# 1108                      Blood On Me  4dblKUfR2u2iQXCQ82awv6
# 1109            Comprehension Barrier  311YHO61J97y3NEmzgXslq
#
#                               album release_date  danceability  ...  \
# 0     THE TORTURED POETS DEPARTMENT   2024-04-18         0.504  ...
# 1     THE TORTURED POETS DEPARTMENT   2024-04-18         0.504  ...
# 2     THE TORTURED POETS DEPARTMENT   2024-04-18         0.701  ...
# 3     THE TORTURED POETS DEPARTMENT   2024-04-18         0.541  ...
# 4                             Lover   2019-08-23         0.552  ...
# ...                             ...          ...           ...  ...
# 1105                  VOYD Vol. 1.5   2019-08-09         0.850  ...
# 1106                    VOYD Vol. I   2018-07-30         0.891  ...
# 1107        MELLODEATH Tapes Vol. I   2024-03-08         0.550  ...
# 1108                    Blood On Me   2020-08-21         0.720  ...
# 1109                   VOYD Vol. II   2022-03-18         0.723  ...
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000015    0.0961    0.281  192.004  audio_features
# 1             0.000015    0.0961    0.281  192.004  audio_features
# 2             0.000000    0.1500    0.220  129.994  audio_features
# 3             0.000001    0.0946    0.168  159.707  audio_features
# 4             0.000021    0.1050    0.564  169.994  audio_features
# ...                ...       ...      ...      ...             ...
# 1105          0.567000    0.0302    0.564  139.878  audio_features
# 1106          0.142000    0.0768    0.555  139.933  audio_features
# 1107          0.000114    0.5050    0.568  140.024  audio_features
# 1108          0.000447    0.1200    0.346  140.043  audio_features
# 1109          0.884000    0.2610    0.209  139.935  audio_features
#
#                                        uri  \
# 0     spotify:track:2OzhQlSqBEmt7hmkYxfT6m
# 1     spotify:track:2OzhQlSqBEmt7hmkYxfT6m
# 2     spotify:track:4q5YezDOIPcoLr8R81x9qy
# 3     spotify:track:2F3N9tdombb64aW6VtZOdo
# 4     spotify:track:1BxfuPKGuaTgP7aM0Bbdwr
# ...                                    ...
# 1105  spotify:track:0tkwUKjhuBA5UuA95JY2bU
# 1106  spotify:track:4o7Rszx7VVCzrCr1RPlPot
# 1107  spotify:track:7q8P4LHGckqsQt4uFnUQ5N
# 1108  spotify:track:4dblKUfR2u2iQXCQ82awv6
# 1109  spotify:track:311YHO61J97y3NEmzgXslq
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/2OzhQlSqBEmt...
# 1     https://api.spotify.com/v1/tracks/2OzhQlSqBEmt...
# 2     https://api.spotify.com/v1/tracks/4q5YezDOIPco...
# 3     https://api.spotify.com/v1/tracks/2F3N9tdombb6...
# 4     https://api.spotify.com/v1/tracks/1BxfuPKGuaTg...
# ...                                                 ...
# 1105  https://api.spotify.com/v1/tracks/0tkwUKjhuBA5...
# 1106  https://api.spotify.com/v1/tracks/4o7Rszx7VVCz...
# 1107  https://api.spotify.com/v1/tracks/7q8P4LHGckqs...
# 1108  https://api.spotify.com/v1/tracks/4dblKUfR2u2i...
# 1109  https://api.spotify.com/v1/tracks/311YHO61J97y...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/2Ozh...       228965
# 1     https://api.spotify.com/v1/audio-analysis/2Ozh...       228965
# 2     https://api.spotify.com/v1/audio-analysis/4q5Y...       218005
# 3     https://api.spotify.com/v1/audio-analysis/2F3N...       261228
# 4     https://api.spotify.com/v1/audio-analysis/1Bxf...       178427
# ...                                                 ...          ...
# 1105  https://api.spotify.com/v1/audio-analysis/0tkw...       114857
# 1106  https://api.spotify.com/v1/audio-analysis/4o7R...       192000
# 1107  https://api.spotify.com/v1/audio-analysis/7q8P...       185143
# 1108  https://api.spotify.com/v1/audio-analysis/4dbl...       192000
# 1109  https://api.spotify.com/v1/audio-analysis/311Y...       161143
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 1105               4
# 1106               4
# 1107               4
# 1108               4
# 1109               4
#
# [1110 rows x 26 columns]

# %% [markdown]
# # Guardar DFs sin Procesar

# %%
# Esto está ya incorporado en la función Create
# directory = "./df_unprocessed/"
# if not os.path.exists(directory):
#     os.makedirs(directory)
# df.to_pickle("./df_unprocessed/df_top50_unprocessed.pkl")
